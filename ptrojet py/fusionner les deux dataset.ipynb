# %%
import pandas as pd

# %%
data_y=pd.read_csv("2_dataset_activities_cleaned.csv")
data_y.shape
# Out:
# (738, 4)

# %%
data_y.head()
# Out:
#   Molecule_ChEMBL_ID  Standard_Value  \
# 0       CHEMBL240055            0.30
# 1      CHEMBL1091513            0.65
# 2      CHEMBL4110988            0.70
# 3      CHEMBL3898248            0.70
# 4      CHEMBL3939963            0.80
#
#                                               Smiles molecule_class
# 0  O=C(OC1([C@H]2CCC[C@@H](c3cc(F)cc(F)c3)N2S(=O)...         active
# 1  O=S(=O)(NC1CCC(c2cc(F)ccc2F)(S(=O)(=O)c2ccc(Cl...         active
# 2  CO[C@H]1CC[C@]2(CC1)Cc1ccc(C#CC(C)C)cc1[C@]21N...         active
# 3  CO[C@H]1CC[C@]2(CC1)Cc1ccc(OCCC(F)(F)F)cc1[C@@...         active
# 4  CO[C@H]1CC[C@]2(CC1)Cc1ccc(OCCC3CC3)cc1C21N=C(...         active

# %%
data_x=pd.read_csv("3_data_moleculaire_desc_cleaned.csv")
data_x.shape
# Out:
# (1031, 26)

# %%
data_x.head()
# Out:
#   Molecule_ChEMBL_ID  Max Phase  Molecular Weight  Targets  Bioactivities  \
# 0      CHEMBL3751854          0            324.41        5              7
# 1        CHEMBL32749          0            194.19      267           1092
# 2      CHEMBL3818600          0            412.45        6             24
# 3       CHEMBL231160          0            632.89       14             57
# 4      CHEMBL3740667          0            175.19        1              3
#
#    AlogP  Polar Surface Area  HBA  HBD  #RO5 Violations  ...  Structure Type  \
# 0   4.00               51.22  4.0  1.0              0.0  ...             MOL
# 1   1.50               66.76  3.0  2.0              0.0  ...             MOL
# 2   3.70               70.83  5.0  0.0              0.0  ...             MOL
# 3   6.27               83.14  8.0  2.0              2.0  ...             MOL
# 4   1.19               45.56  3.0  0.0              0.0  ...             MOL
#
# ...

# %%
data=pd.merge(data_y,data_x,on="Molecule_ChEMBL_ID",how="left")
data.head()
# Out:
#   Molecule_ChEMBL_ID  Standard_Value  \
# 0       CHEMBL240055            0.30
# 1      CHEMBL1091513            0.65
# 2      CHEMBL4110988            0.70
# 3      CHEMBL3898248            0.70
# 4      CHEMBL3939963            0.80
#
#                                             Smiles_x molecule_class  \
# 0  O=C(OC1([C@H]2CCC[C@@H](c3cc(F)cc(F)c3)N2S(=O)...         active
# 1  O=S(=O)(NC1CCC(c2cc(F)ccc2F)(S(=O)(=O)c2ccc(Cl...         active
# 2  CO[C@H]1CC[C@]2(CC1)Cc1ccc(C#CC(C)C)cc1[C@]21N...         active
# 3  CO[C@H]1CC[C@]2(CC1)Cc1ccc(OCCC(F)(F)F)cc1[C@@...         active
# 4  CO[C@H]1CC[C@]2(CC1)Cc1ccc(OCCC3CC3)cc1C21N=C(...         active
#
#    Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0        0.0            622.18      2.0            2.0   6.52
# 1        0.0            517.93    443.0          525.0   4.67
# 2        0.0            363.51      2.0            2.0   3.81
# 3        0.0            409.45      2.0            2.0   4.13
# ...

# %%
data.shape
# Out:
# (738, 29)

# %%
data.columns
# Out:
# Index(['Molecule_ChEMBL_ID', 'Standard_Value', 'Smiles_x', 'molecule_class',
#        'Max Phase', 'Molecular Weight', 'Targets', 'Bioactivities', 'AlogP',
#        'Polar Surface Area', 'HBA', 'HBD', '#RO5 Violations',
#        '#Rotatable Bonds', 'Passes Ro3', 'QED Weighted', 'CX LogP', 'CX LogD',
#        'Aromatic Rings', 'Structure Type', 'Inorganic Flag', 'Heavy Atoms',
#        'HBA (Lipinski)', 'HBD (Lipinski)', '#RO5 Violations (Lipinski)',
#        'Molecular Weight (Monoisotopic)', 'Molecular Species',
#        'Molecular Formula', 'Smiles_y'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Molecule_ChEMBL_ID                 0
# Standard_Value                     0
# Smiles_x                           0
# molecule_class                     0
# Max Phase                          4
# Molecular Weight                   4
# Targets                            4
# Bioactivities                      4
# AlogP                              4
# Polar Surface Area                 4
# HBA                                4
# HBD                                4
# #RO5 Violations                    4
# #Rotatable Bonds                   4
# Passes Ro3                         4
# QED Weighted                       4
# CX LogP                            4
# CX LogD                            4
# Aromatic Rings                     4
# Structure Type                     4
# Inorganic Flag                     4
# Heavy Atoms                        4
# HBA (Lipinski)                     4
# HBD (Lipinski)                     4
# #RO5 Violations (Lipinski)         4
# ...

# %%
df_drop_row= data.dropna(axis=0,thresh=5)
df_drop_row.shape
# Out:
# (734, 29)

# %%
df_drop_row.isnull().sum().sum()
# Out:
# 0

# %%
df_drop_row.isnull().sum()
# Out:
# Molecule_ChEMBL_ID                 0
# Standard_Value                     0
# Smiles_x                           0
# molecule_class                     0
# Max Phase                          0
# Molecular Weight                   0
# Targets                            0
# Bioactivities                      0
# AlogP                              0
# Polar Surface Area                 0
# HBA                                0
# HBD                                0
# #RO5 Violations                    0
# #Rotatable Bonds                   0
# Passes Ro3                         0
# QED Weighted                       0
# CX LogP                            0
# CX LogD                            0
# Aromatic Rings                     0
# Structure Type                     0
# Inorganic Flag                     0
# Heavy Atoms                        0
# HBA (Lipinski)                     0
# HBD (Lipinski)                     0
# #RO5 Violations (Lipinski)         0
# ...

# %%
df_drop_row.to_csv("data_final.csv" ,index=False)
